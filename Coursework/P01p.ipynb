# %% [markdown]
# <a href="https://colab.research.google.com/github/P4CSS/PSS/blob/master/P01p.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install facebook-scraper
# Out:
# ...
#      ---------------------------------------- 45.5/45.5 kB 1.1 MB/s eta 0:00:00
# ...
#      -------------------------------------- 292.7/292.7 kB 2.0 MB/s eta 0:00:00
# ...
#      -------------------------------------- 131.5/131.5 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 274.4/274.4 kB 5.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 83.4/83.4 kB 4.9 MB/s eta 0:00:00
# ...
#   Using cached bs4-0.0.1-py3-none-any.whl
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      -------------------------------------- 101.4/101.4 kB 2.9 MB/s eta 0:00:00
# ...
#      -------------------------------------- 338.8/338.8 kB 3.5 MB/s eta 0:00:00
# ...
#   Created wheel for demjson3: filename=demjson3-3.0.6-py3-none-any.whl size=75281 sha256=eb42e2f72600bc6649de1b8078ccac285f6d5ee8f05d786a4a08c7f07a099c67
# ...

# %%
# %pip install browser-cookie3
# Out:
# ...
#      ---------------------------------------- 1.9/1.9 MB 3.3 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 98.9/98.9 kB 2.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 48.4/48.4 kB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 52.8/52.8 kB 2.8 MB/s eta 0:00:00
# ...
#   Created wheel for pbkdf2: filename=pbkdf2-1.3-py3-none-any.whl size=5083 sha256=55578d636b2e4f264f4b6336217ac56c7a5c4aa0578d079284804bba77e667b5
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\8a\bc\b5\384fdb7fc125e4d3d25b92eb8365b87c8b652a7096fcdcc16e
# ...
#   Created wheel for pyaes: filename=pyaes-1.6.1-py3-none-any.whl size=26347 sha256=13cb0f299be20908e18cf0f6d689c068088e69de44c85eed8e51869381d96833
# ...

# %%
from facebook_scraper import get_posts
for post in get_posts('zelenskiy.official', page = 3):
    print(post['post_text'])
# Out:
# There is a conclusion of the IAEA today - it is quite obvious. The organization's mission visited all the objects that Russian representatives mentioned when they told their fantasies about the so-called dirty更多 bomb.
#
# We have invited the IAEA to check, we have given them full freedom of action at the relevant facilities, and we have clear and irrefutable evidence that no one in Ukraine has created or is creating any "dirty bombs". And the only thing that is dirty in our region now is the heads of those in Moscow who, unfortunately, seized control of the Russian state and are terrorizing Ukraine and the whole world.
#
# Glory to all who defend our state! Glory to all who fight and work, bringing our victory closer!
#
# As for the front, the guys are moving forward. As for the grain, the ships are on their way. As for the occupiers, they are also on their way... following the warships!
# Glory to Ukraine!
# ...

# %% [markdown]
# # Self-Quiz: Counting departments
# 以下的stu_list為一群修課生的科系，現在要列數每個科系有多少人修課。

# %%
stu_dict = {}
stu_list = ["soc", "soc", "econ", "bio", "psy", "psy", "econ", "poli", "econ"]

# %% [markdown]
# ## Counting with for-loop
# 以下為其中一種可能的寫法，不盡然要照著邏輯寫，可以自己寫寫看。
# ```
# Output:
# {'soc': 2, 'econ': 3, 'bio': 1, 'psy': 2, 'poli': 1}`
# ```

# %%
# Out:
# {'soc': 2, 'econ': 3, 'bio': 1, 'psy': 2, 'poli': 1}

# %% [markdown]
# ## Print out all keys and value()
# ```
# Output：
# dict_keys(['soc', 'econ', 'bio', 'psy', 'poli'])
# dict_values([2, 3, 1, 2, 1])
# ```

# %%
# Out:
# dict_keys(['soc', 'econ', 'bio', 'psy', 'poli'])
# dict_values([2, 3, 1, 2, 1])

# %% [markdown]
# ## Print out all pairs by items()
# ```
# Output:
# dict_items([('soc', 2), ('econ', 3), ('bio', 1), ('psy', 2), ('poli', 1)])
# ```

# %%
# Out:
# dict_items([('soc', 2), ('econ', 3), ('bio', 1), ('psy', 2), ('poli', 1)])

# %% [markdown]
# ## Counting by Counter()
# ```
# Output:
# Counter({'econ': 3, 'soc': 2, 'psy': 2, 'bio': 1, 'poli': 1})
# econ 3
# soc 2
# psy 2
# bio 1
# poli 1
# ```

# %%
# Out:
# Counter({'econ': 3, 'soc': 2, 'psy': 2, 'bio': 1, 'poli': 1})
# econ 3
# soc 2
# psy 2
# bio 1
# poli 1
